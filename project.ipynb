# %%
import pandas as pd

# %%
data1=pd.read_excel('invoice_fact_table.xlsx')

# %%
print(data1)
# Out:
#       ORDERNUMBER PRODUCTCODE              CUSTOMERNAME  COUNTRY  DATE_ID  \
# 0           10107    S10_1678         Land of Toys Inc.      USA        1
# 1           10121    S10_1678        Reims Collectables   France        2
# 2           10134    S10_1678           Lyon Souveniers   France        3
# 3           10145    S10_1678         Toys4GrownUps.com      USA        4
# 4           10159    S10_1678  Corporate Gift Ideas Co.      USA        5
# ...           ...         ...                       ...      ...      ...
# 2818        10350    S72_3212     Euro Shopping Channel    Spain       83
# 2819        10373    S72_3212   Oulu Toy Supplies, Inc.  Finland       85
# 2820        10386    S72_3212     Euro Shopping Channel    Spain      197
# 2821        10397    S72_3212              Alpha Cognac   France      251
# 2822        10414    S72_3212         Gifts4AllAges.com      USA       89
#
#       QUANTITYORDERED  PRICEEACH    SALES  ORDERLINENUMBER PAYMENT_METHOD
# ...

# %%
data1.head(10)
# Out:
#    ORDERNUMBER PRODUCTCODE              CUSTOMERNAME COUNTRY  DATE_ID  \
# 0        10107    S10_1678         Land of Toys Inc.     USA        1
# 1        10121    S10_1678        Reims Collectables  France        2
# 2        10134    S10_1678           Lyon Souveniers  France        3
# 3        10145    S10_1678         Toys4GrownUps.com     USA        4
# 4        10159    S10_1678  Corporate Gift Ideas Co.     USA        5
# 5        10168    S10_1678      Technics Stores Inc.     USA        6
# 6        10180    S10_1678  Daedalus Designs Imports  France        7
# 7        10188    S10_1678              Herkku Gifts  Norway        8
# 8        10201    S10_1678           Mini Wheels Co.     USA        9
# 9        10211    S10_1678          Auto Canal Petit  France       10
#
#    QUANTITYORDERED  PRICEEACH    SALES  ORDERLINENUMBER PAYMENT_METHOD
# 0               30      95.70  2871.00                2    Credit Card
# ...

# %%
data1.COUNTRY.value_counts()
# Out:
# COUNTRY
# USA            1004
# Spain           342
# France          314
# Australia       185
# UK              144
# Italy           113
# Finland          92
# Norway           85
# Singapore        79
# Canada           70
# Denmark          63
# Germany          62
# Sweden           57
# Austria          55
# Japan            52
# Belgium          33
# Switzerland      31
# Philippines      26
# Ireland          16
# Name: count, dtype: int64

# %%
data1.COUNTRY.unique()
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %%
data1.isnull()
# Out:
#       ORDERNUMBER  PRODUCTCODE  CUSTOMERNAME  COUNTRY  DATE_ID  \
# 0           False        False         False    False    False
# 1           False        False         False    False    False
# 2           False        False         False    False    False
# 3           False        False         False    False    False
# 4           False        False         False    False    False
# ...           ...          ...           ...      ...      ...
# 2818        False        False         False    False    False
# 2819        False        False         False    False    False
# 2820        False        False         False    False    False
# 2821        False        False         False    False    False
# 2822        False        False         False    False    False
#
#       QUANTITYORDERED  PRICEEACH  SALES  ORDERLINENUMBER  PAYMENT_METHOD
# 0               False      False  False            False           False
# ...

# %%
data1.isnull().sum()
# Out:
# ORDERNUMBER        0
# PRODUCTCODE        0
# CUSTOMERNAME       0
# COUNTRY            0
# DATE_ID            0
# QUANTITYORDERED    0
# PRICEEACH          0
# SALES              0
# ORDERLINENUMBER    0
# PAYMENT_METHOD     0
# dtype: int64

# %%
df1=data1

# %%
df1.tail()
# Out:
#       ORDERNUMBER PRODUCTCODE             CUSTOMERNAME  COUNTRY  DATE_ID  \
# 2818        10350    S72_3212    Euro Shopping Channel    Spain       83
# 2819        10373    S72_3212  Oulu Toy Supplies, Inc.  Finland       85
# 2820        10386    S72_3212    Euro Shopping Channel    Spain      197
# 2821        10397    S72_3212             Alpha Cognac   France      251
# 2822        10414    S72_3212        Gifts4AllAges.com      USA       89
#
#       QUANTITYORDERED  PRICEEACH    SALES  ORDERLINENUMBER PAYMENT_METHOD
# 2818               20     100.00  2244.40               15           Cash
# 2819               29     100.00  3978.51                1    Credit Card
# 2820               43     100.00  5417.57                4    Credit Card
# 2821               34      62.24  2116.16                1           Cash
# 2822               47      65.52  3079.44                9    Credit Card

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ORDERNUMBER      2823 non-null   int64
#  1   PRODUCTCODE      2823 non-null   object
#  2   CUSTOMERNAME     2823 non-null   object
#  3   COUNTRY          2823 non-null   object
#  4   DATE_ID          2823 non-null   int64
#  5   QUANTITYORDERED  2823 non-null   int64
#  6   PRICEEACH        2823 non-null   float64
#  7   SALES            2823 non-null   float64
#  8   ORDERLINENUMBER  2823 non-null   int64
#  9   PAYMENT_METHOD   2823 non-null   object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 220.7+ KB

# %%
df1.describe()
# Out:
#         ORDERNUMBER      DATE_ID  QUANTITYORDERED    PRICEEACH         SALES  \
# count   2823.000000  2823.000000      2823.000000  2823.000000   2823.000000
# mean   10258.725115   106.357067        35.092809    83.658544   3553.889072
# std       92.085478    65.229085         9.741443    20.174277   1841.865106
# min    10100.000000     1.000000         6.000000    26.880000    482.130000
# 25%    10180.000000    50.000000        27.000000    68.860000   2203.430000
# 50%    10262.000000   101.000000        35.000000    95.700000   3184.800000
# 75%    10333.500000   160.000000        43.000000   100.000000   4508.000000
# max    10425.000000   252.000000        97.000000   100.000000  14082.800000
#
#        ORDERLINENUMBER
# count      2823.000000
# mean          6.466171
# std           4.225841
# min           1.000000
# 25%           3.000000
# 50%           6.000000
# 75%           9.000000
# max          18.000000

# %%
df1.shape
# Out:
# (2823, 10)

# %%
df1.dtypes
# Out:
# ORDERNUMBER          int64
# PRODUCTCODE         object
# CUSTOMERNAME        object
# COUNTRY             object
# DATE_ID              int64
# QUANTITYORDERED      int64
# PRICEEACH          float64
# SALES              float64
# ORDERLINENUMBER      int64
# PAYMENT_METHOD      object
# dtype: object

# %%
df1.columns
# Out:
# Index(['ORDERNUMBER', 'PRODUCTCODE', 'CUSTOMERNAME', 'COUNTRY', 'DATE_ID',
#        'QUANTITYORDERED', 'PRICEEACH', 'SALES', 'ORDERLINENUMBER',
#        'PAYMENT_METHOD'],
#       dtype='object')

# %%
df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# Length: 2823, dtype: bool

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.COUNTRY.value_counts()
# Out:
# COUNTRY
# USA            1004
# Spain           342
# France          314
# Australia       185
# UK              144
# Italy           113
# Finland          92
# Norway           85
# Singapore        79
# Canada           70
# Denmark          63
# Germany          62
# Sweden           57
# Austria          55
# Japan            52
# Belgium          33
# Switzerland      31
# Philippines      26
# Ireland          16
# Name: count, dtype: int64

# %% [markdown]
# country_dimension

# %%
data2=pd.read_excel('country_dimension.xlsx')

# %%
print(data2)
# Out:
#         COUNTRY      TERRITORY CURRENCY
# 0           USA  North America      USD
# 1        France         Europe      EUR
# 2        Norway         Europe      NOK
# 3     Australia           APAC      AUD
# 4       Finland         Europe      EUR
# 5       Austria         Europe      EUR
# 6            UK         Europe      GBP
# 7         Spain         Europe      EUR
# 8        Sweden         Europe      SEK
# 9     Singapore           APAC      SGD
# 10       Canada  North America      USD
# 11        Japan           APAC      JPY
# 12        Italy         Europe      EUR
# 13      Denmark         Europe      DKK
# 14      Belgium         Europe      EUR
# 15    Singapore           APAC      SGD
# 16  Philippines           APAC      PHP
# 17      Germany         Europe      EUR
# 18  Switzerland         Europe      CHF
# 19      Ireland         Europe      EUR

# %%
data2.head(10)
# Out:
#      COUNTRY      TERRITORY CURRENCY
# 0        USA  North America      USD
# 1     France         Europe      EUR
# 2     Norway         Europe      NOK
# 3  Australia           APAC      AUD
# 4    Finland         Europe      EUR
# 5    Austria         Europe      EUR
# 6         UK         Europe      GBP
# 7      Spain         Europe      EUR
# 8     Sweden         Europe      SEK
# 9  Singapore           APAC      SGD

# %%
data2.TERRITORY.value_counts()
# Out:
# TERRITORY
# Europe           13
# APAC              5
# North America     2
# Name: count, dtype: int64

# %%
data2.CURRENCY.unique()
# Out:
# array(['USD', 'EUR', 'NOK', 'AUD', 'GBP', 'SEK', 'SGD', 'JPY', 'DKK',
#        'PHP', 'CHF'], dtype=object)

# %%
data2.isnull()
# Out:
#     COUNTRY  TERRITORY  CURRENCY
# 0     False      False     False
# 1     False      False     False
# 2     False      False     False
# 3     False      False     False
# 4     False      False     False
# 5     False      False     False
# 6     False      False     False
# 7     False      False     False
# 8     False      False     False
# 9     False      False     False
# 10    False      False     False
# 11    False      False     False
# 12    False      False     False
# 13    False      False     False
# 14    False      False     False
# 15    False      False     False
# 16    False      False     False
# 17    False      False     False
# 18    False      False     False
# 19    False      False     False

# %%
data2.isnull().sum()
# Out:
# COUNTRY      0
# TERRITORY    0
# CURRENCY     0
# dtype: int64

# %%
df2=data2

# %%
df2.tail()
# Out:
#         COUNTRY TERRITORY CURRENCY
# 15    Singapore      APAC      SGD
# 16  Philippines      APAC      PHP
# 17      Germany    Europe      EUR
# 18  Switzerland    Europe      CHF
# 19      Ireland    Europe      EUR

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   COUNTRY    20 non-null     object
#  1   TERRITORY  20 non-null     object
#  2   CURRENCY   20 non-null     object
# dtypes: object(3)
# memory usage: 612.0+ bytes

# %%
df2.describe()
# Out:
#           COUNTRY TERRITORY CURRENCY
# count          20        20       20
# unique         19         3       11
# top     Singapore    Europe      EUR
# freq            2        13        8

# %%
df2.shape
# Out:
# (20, 3)

# %%
df2.dtypes
# Out:
# COUNTRY      object
# TERRITORY    object
# CURRENCY     object
# dtype: object

# %%
df2.columns
# Out:
# Index(['COUNTRY', 'TERRITORY', 'CURRENCY'], dtype='object')

# %%
df2.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df2.duplicated().sum()
# Out:
# 1

# %%
df2.TERRITORY.value_counts()
# Out:
# TERRITORY
# Europe           13
# APAC              5
# North America     2
# Name: count, dtype: int64

# %% [markdown]
# customer_dimension

# %%
data3=pd.read_excel('/content/customer_dimension.xlsx')

# %%
print(data3)
# Out:
#                           CUSTOMERNAME CONTACTFIRSTNAME CONTACTLASTNAME  \
# 0                    Land of Toys Inc.             Kwai              Yu
# 1                   Reims Collectables             Paul         Henriot
# 2                      Lyon Souveniers           Daniel        Da Cunha
# 3                    Toys4GrownUps.com            Julie           Young
# 4             Corporate Gift Ideas Co.            Julie           Brown
# ..                                 ...              ...             ...
# 87        Australian Collectables, Ltd             Sean         Connery
# 88                    Gift Ideas Corp.              Dan           Lewis
# 89  Bavarian Collectables Imports, Co.          Michael     Donnermeyer
# 90                        Royale Belge          Pascale        Cartrain
# 91             Auto-Moto Classics Inc.           Leslie          Taylor
#
#                 PHONE                   ADDRESSLINE1 ADDRESSLINE2  \
# ...

# %%
data3.head(10)
# Out:
#                CUSTOMERNAME CONTACTFIRSTNAME CONTACTLASTNAME  \
# 0         Land of Toys Inc.             Kwai              Yu
# 1        Reims Collectables             Paul         Henriot
# 2           Lyon Souveniers           Daniel        Da Cunha
# 3         Toys4GrownUps.com            Julie           Young
# 4  Corporate Gift Ideas Co.            Julie           Brown
# 5      Technics Stores Inc.             Juri          Hirano
# 6  Daedalus Designs Imports          Martine           Rance
# 7              Herkku Gifts           Veysel          Oeztan
# 8           Mini Wheels Co.            Julie          Murphy
# 9          Auto Canal Petit        Dominique         Perrier
#
#               PHONE                   ADDRESSLINE1 ADDRESSLINE2  \
# 0        2125557818        897 Long Airport Avenue          NaN
# 1        26.47.1555             59 rue de l'Abbaye          NaN
# 2  +33 1 46 62 7555  27 rue du Colonel Pierre Avia          NaN
# ...

# %%
data3.CITY.value_counts()
# Out:
# CITY
# NYC           5
# Brickhaven    3
# Madrid        3
# Paris         3
# Singapore     2
#              ..
# Nashua        1
# Reims         1
# Montreal      1
# Osaka         1
# Charleroi     1
# Name: count, Length: 73, dtype: int64

# %%
data3.CITY.unique()
# Out:
# array(['NYC', 'Reims', 'Paris', 'Pasadena', 'San Francisco', 'Burlingame',
#        'Lille', 'Bergen', 'Melbourne', 'Newark', 'Bridgewater', 'Nantes',
#        'Cambridge', 'Helsinki', 'Stavern', 'Allentown', 'Salzburg',
#        'Chatswood', 'New Bedford', 'Liverpool', 'Madrid', 'Lule',
#        'Singapore', 'South Brisbane', 'Philadelphia', 'Lyon', 'Vancouver',
#        'Burbank', 'New Haven', 'Minato-ku', 'Torino', 'Boras',
#        'Versailles', 'San Rafael', 'Nashua', 'Brickhaven', 'North Sydney',
#        'Montreal', 'Osaka', 'White Plains', 'Kobenhavn', 'London',
#        'Toulouse', 'Barcelona', 'Los Angeles', 'San Diego', 'Bruxelles',
#        'Tsawassen', 'Boston', 'Cowes', 'Oulu', 'San Jose', 'Graz',
#        'Makati City', 'Marseille', 'Koln', 'Gensve', 'Reggio Emilia',
#        'Frankfurt', 'Espoo', 'Dublin', 'Manchester', 'Aaarhus',
#        'Glendale', 'Sevilla', 'Brisbane', 'Strasbourg', 'Las Vegas',
#        'Oslo', 'Bergamo', 'Glen Waverly', 'Munich', 'Charleroi'],
# ...

# %%
data3.isnull()
# Out:
#     CUSTOMERNAME  CONTACTFIRSTNAME  CONTACTLASTNAME  PHONE  ADDRESSLINE1  \
# 0          False             False            False  False         False
# 1          False             False            False  False         False
# 2          False             False            False  False         False
# 3          False             False            False  False         False
# 4          False             False            False  False         False
# ..           ...               ...              ...    ...           ...
# 87         False             False            False  False         False
# 88         False             False            False  False         False
# 89         False             False            False  False         False
# 90         False             False            False  False         False
# 91         False             False            False  False         False
#
#     ADDRESSLINE2   CITY  STATE  POSTALCODE  FIRST_PURCHASE_DATE
# ...

# %%
data3.isnull().sum()
# Out:
# CUSTOMERNAME            0
# CONTACTFIRSTNAME        0
# CONTACTLASTNAME         0
# PHONE                   0
# ADDRESSLINE1            0
# ADDRESSLINE2           83
# CITY                    0
# STATE                  46
# POSTALCODE              3
# FIRST_PURCHASE_DATE     0
# dtype: int64

# %%
df3=data3

# %%
df3.tail()
# Out:
#                           CUSTOMERNAME CONTACTFIRSTNAME CONTACTLASTNAME  \
# 87        Australian Collectables, Ltd             Sean         Connery
# 88                    Gift Ideas Corp.              Dan           Lewis
# 89  Bavarian Collectables Imports, Co.          Michael     Donnermeyer
# 90                        Royale Belge          Pascale        Cartrain
# 91             Auto-Moto Classics Inc.           Leslie          Taylor
#
#                 PHONE          ADDRESSLINE1 ADDRESSLINE2          CITY  \
# 87     61-9-3844-6555        7 Allen Street          NaN  Glen Waverly
# 88         2035554407      2440 Pompton St.          NaN      Glendale
# 89  +49 89 61 08 9555          Hansastr. 15          NaN        Munich
# 90   (071) 23 67 2555  Boulevard Tirou, 255          NaN     Charleroi
# 91         6175558428     16780 Pompton St.          NaN    Brickhaven
#
#        STATE POSTALCODE FIRST_PURCHASE_DATE
# 87  Victoria       3150          2003-11-21
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CUSTOMERNAME         92 non-null     object
#  1   CONTACTFIRSTNAME     92 non-null     object
#  2   CONTACTLASTNAME      92 non-null     object
#  3   PHONE                92 non-null     object
#  4   ADDRESSLINE1         92 non-null     object
#  5   ADDRESSLINE2         9 non-null      object
#  6   CITY                 92 non-null     object
#  7   STATE                46 non-null     object
#  8   POSTALCODE           89 non-null     object
#  9   FIRST_PURCHASE_DATE  92 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(9)
# memory usage: 7.3+ KB

# %%
df3.describe()
# Out:
#                  FIRST_PURCHASE_DATE
# count                             92
# mean   2003-09-27 12:31:18.260869504
# min              2003-01-06 00:00:00
# 25%              2003-05-17 00:00:00
# 50%              2003-10-08 00:00:00
# 75%              2003-12-17 12:00:00
# max              2004-09-15 00:00:00

# %%
df3.shape
# Out:
# (92, 10)

# %%
df3.dtypes
# Out:
# CUSTOMERNAME                   object
# CONTACTFIRSTNAME               object
# CONTACTLASTNAME                object
# PHONE                          object
# ADDRESSLINE1                   object
# ADDRESSLINE2                   object
# CITY                           object
# STATE                          object
# POSTALCODE                     object
# FIRST_PURCHASE_DATE    datetime64[ns]
# dtype: object

# %%
df3.columns
# Out:
# Index(['CUSTOMERNAME', 'CONTACTFIRSTNAME', 'CONTACTLASTNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'FIRST_PURCHASE_DATE'],
#       dtype='object')

# %%
df3.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 87    False
# 88    False
# 89    False
# 90    False
# 91    False
# Length: 92, dtype: bool

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df3.CITY.value_counts()
# Out:
# CITY
# NYC           5
# Brickhaven    3
# Madrid        3
# Paris         3
# Singapore     2
#              ..
# Nashua        1
# Reims         1
# Montreal      1
# Osaka         1
# Charleroi     1
# Name: count, Length: 73, dtype: int64

# %% [markdown]
# date_dimension

# %%
data4=pd.read_excel('date_dimension.xlsx')

# %%
print(data4)
# Out:
#      ORDERDATE DAY_TYPE  MONTH  QUARTER  YEAR  DATE_ID
# 0   2003-02-24  Weekday      2        1  2003        1
# 1   2003-05-07  Weekday      5        2  2003        2
# 2   2003-07-01  Weekday      7        3  2003        3
# 3   2003-08-25  Weekday      8        3  2003        4
# 4   2003-10-10  Weekday     10        4  2003        5
# ..         ...      ...    ...      ...   ...      ...
# 247 2003-04-11  Weekday      4        2  2003      248
# 248 2003-08-13  Weekday      8        3  2003      249
# 249 2003-10-08  Weekday     10        4  2003      250
# 250 2005-03-28  Weekday      3        1  2005      251
# 251 2003-04-21  Weekday      4        2  2003      252
#
# [252 rows x 6 columns]

# %%
data4.head(10)
# Out:
#    ORDERDATE DAY_TYPE  MONTH  QUARTER  YEAR  DATE_ID
# 0 2003-02-24  Weekday      2        1  2003        1
# 1 2003-05-07  Weekday      5        2  2003        2
# 2 2003-07-01  Weekday      7        3  2003        3
# 3 2003-08-25  Weekday      8        3  2003        4
# 4 2003-10-10  Weekday     10        4  2003        5
# 5 2003-10-28  Weekday     10        4  2003        6
# 6 2003-11-11  Weekday     11        4  2003        7
# 7 2003-11-18  Weekday     11        4  2003        8
# 8 2003-12-01  Weekday     12        4  2003        9
# 9 2004-01-15  Weekday      1        1  2004       10

# %%
data4.DATE_ID.value_counts()
# Out:
# DATE_ID
# 1      1
# 174    1
# 161    1
# 162    1
# 163    1
#       ..
# 89     1
# 90     1
# 91     1
# 92     1
# 252    1
# Name: count, Length: 252, dtype: int64

# %%
data4.YEAR.unique()
# Out:
# array([2003, 2004, 2005])

# %%
data4.isnull()
# Out:
#      ORDERDATE  DAY_TYPE  MONTH  QUARTER   YEAR  DATE_ID
# 0        False     False  False    False  False    False
# 1        False     False  False    False  False    False
# 2        False     False  False    False  False    False
# 3        False     False  False    False  False    False
# 4        False     False  False    False  False    False
# ..         ...       ...    ...      ...    ...      ...
# 247      False     False  False    False  False    False
# 248      False     False  False    False  False    False
# 249      False     False  False    False  False    False
# 250      False     False  False    False  False    False
# 251      False     False  False    False  False    False
#
# [252 rows x 6 columns]

# %%
data4.isnull().sum()
# Out:
# ORDERDATE    0
# DAY_TYPE     0
# MONTH        0
# QUARTER      0
# YEAR         0
# DATE_ID      0
# dtype: int64

# %%
df4=data4

# %%
df4.tail()
# Out:
#      ORDERDATE DAY_TYPE  MONTH  QUARTER  YEAR  DATE_ID
# 247 2003-04-11  Weekday      4        2  2003      248
# 248 2003-08-13  Weekday      8        3  2003      249
# 249 2003-10-08  Weekday     10        4  2003      250
# 250 2005-03-28  Weekday      3        1  2005      251
# 251 2003-04-21  Weekday      4        2  2003      252

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ORDERDATE  252 non-null    datetime64[ns]
#  1   DAY_TYPE   252 non-null    object
#  2   MONTH      252 non-null    int64
#  3   QUARTER    252 non-null    int64
#  4   YEAR       252 non-null    int64
#  5   DATE_ID    252 non-null    int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 11.9+ KB

# %%
df4.describe()
# Out:
#                            ORDERDATE       MONTH     QUARTER         YEAR  \
# count                            252  252.000000  252.000000   252.000000
# mean   2004-05-07 01:48:34.285714304    6.420635    2.492063  2003.861111
# min              2003-01-06 00:00:00    1.000000    1.000000  2003.000000
# 25%              2003-10-26 18:00:00    3.000000    1.000000  2003.000000
# 50%              2004-05-29 00:00:00    6.000000    2.000000  2004.000000
# 75%              2004-11-22 06:00:00   10.000000    4.000000  2004.000000
# max              2005-05-31 00:00:00   12.000000    4.000000  2005.000000
# std                              NaN    3.595821    1.179142     0.720057
#
#           DATE_ID
# count  252.000000
# mean   126.500000
# min      1.000000
# 25%     63.750000
# 50%    126.500000
# 75%    189.250000
# max    252.000000
# std     72.890329

# %%
df4.shape
# Out:
# (252, 6)

# %%
df4.dtypes
# Out:
# ORDERDATE    datetime64[ns]
# DAY_TYPE             object
# MONTH                 int64
# QUARTER               int64
# YEAR                  int64
# DATE_ID               int64
# dtype: object

# %%
df4.columns
# Out:
# Index(['ORDERDATE', 'DAY_TYPE', 'MONTH', 'QUARTER', 'YEAR', 'DATE_ID'], dtype='object')

# %%
df4.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 247    False
# 248    False
# 249    False
# 250    False
# 251    False
# Length: 252, dtype: bool

# %% [markdown]
# product_dimension.xlsx

# %%
data5=pd.read_excel('product_dimension.xlsx')

# %%
print(data5)
# Out:
#     PRODUCTCODE   PRODUCTLINE  MSRP
# 0      S10_1678   Motorcycles    95
# 1      S10_1949  Classic Cars   214
# 2      S10_2016   Motorcycles   118
# 3      S10_4698   Motorcycles   193
# 4      S10_4757  Classic Cars   136
# ..          ...           ...   ...
# 104   S700_3505         Ships   100
# 105   S700_3962         Ships    99
# 106   S700_4002        Planes    74
# 107    S72_1253        Planes    49
# 108    S72_3212         Ships    54
#
# [109 rows x 3 columns]

# %%
data5.head(10)
# Out:
#   PRODUCTCODE       PRODUCTLINE  MSRP
# 0    S10_1678       Motorcycles    95
# 1    S10_1949      Classic Cars   214
# 2    S10_2016       Motorcycles   118
# 3    S10_4698       Motorcycles   193
# 4    S10_4757      Classic Cars   136
# 5    S10_4962      Classic Cars   147
# 6    S12_1099      Classic Cars   194
# 7    S12_1108      Classic Cars   207
# 8    S12_1666  Trucks and Buses   136
# 9    S12_2823       Motorcycles   150

# %%
data5.PRODUCTLINE.value_counts()
# Out:
# PRODUCTLINE
# Classic Cars        37
# Vintage Cars        24
# Motorcycles         13
# Planes              12
# Trucks and Buses    11
# Ships                9
# Trains               3
# Name: count, dtype: int64

# %%
data5.PRODUCTLINE.unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
data5.isnull()
# Out:
#      PRODUCTCODE  PRODUCTLINE   MSRP
# 0          False        False  False
# 1          False        False  False
# 2          False        False  False
# 3          False        False  False
# 4          False        False  False
# ..           ...          ...    ...
# 104        False        False  False
# 105        False        False  False
# 106        False        False  False
# 107        False        False  False
# 108        False        False  False
#
# [109 rows x 3 columns]

# %%
data5.isnull().sum()
# Out:
# PRODUCTCODE    0
# PRODUCTLINE    0
# MSRP           0
# dtype: int64

# %%
df5=data5

# %%
df5.tail()
# Out:
#     PRODUCTCODE PRODUCTLINE  MSRP
# 104   S700_3505       Ships   100
# 105   S700_3962       Ships    99
# 106   S700_4002      Planes    74
# 107    S72_1253      Planes    49
# 108    S72_3212       Ships    54

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRODUCTCODE  109 non-null    object
#  1   PRODUCTLINE  109 non-null    object
#  2   MSRP         109 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 2.7+ KB

# %%
df5.describe()
# Out:
#              MSRP
# count  109.000000
# mean    99.899083
# std     39.824603
# min     33.000000
# 25%     68.000000
# 50%     97.000000
# 75%    122.000000
# max    214.000000

# %%
df5.shape
# Out:
# (109, 3)

# %%
df5.dtypes
# Out:
# PRODUCTCODE    object
# PRODUCTLINE    object
# MSRP            int64
# dtype: object

# %%
df5.columns
# Out:
# Index(['PRODUCTCODE', 'PRODUCTLINE', 'MSRP'], dtype='object')

# %%
df5.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 104    False
# 105    False
# 106    False
# 107    False
# 108    False
# Length: 109, dtype: bool

# %%
df5.duplicated().sum()
# Out:
# 0
